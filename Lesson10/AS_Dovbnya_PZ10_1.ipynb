# %%
import numpy as np
import pandas as pd
import random

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score as r2
from sklearn.model_selection import KFold, GridSearchCV

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Загрузил библиотеки и функции для постройки графиков как у преподавателя. Для проверки эффективности модели.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
matplotlib.rcParams.update({'font.size': 14})

# %%
def evaluate_preds(train_true_values, train_pred_values, test_true_values, test_pred_values):
    print("Train R2:\t" + str(round(r2(train_true_values, train_pred_values), 3)))
    print("Test R2:\t" + str(round(r2(test_true_values, test_pred_values), 3)))
    
    plt.figure(figsize=(18,10))
    
    plt.subplot(121)
    sns.scatterplot(x=train_pred_values, y=train_true_values)
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('Train sample prediction')
    
    plt.subplot(122)
    sns.scatterplot(x=test_pred_values, y=test_true_values)
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('Test sample prediction')

    plt.show()

# %% [markdown]
# ### Загрузка тренировочного и тестового датасетов.

# %%
TRAIN_DATASET_PATH = 'train1.csv'
TEST_DATASET_PATH = 'test1.csv'

# %%
train_df = pd.read_csv(TRAIN_DATASET_PATH)
train_df.head()
# Out:
#       Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0  11809          27    3.0  115.027311         NaN           10.0      4
# 1   3013          22    1.0   39.832524   23.169223            8.0      7
# 2   8215           1    3.0   78.342215   47.671972           10.0      2
# 3   2352           1    1.0   40.409907         NaN            1.0     10
# 4  13866          94    2.0   64.285067   38.562517            9.0     16
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        10.0       2014   0.075424         B         B        11      3097
# 1         8.0       1966   0.118537         B         B        30      6207
# 2        17.0       1988   0.025609         B         B        33      5261
# 3        22.0       1977   0.007122         B         B         1       264
# 4        16.0       1972   0.282798         B         B        33      8667
#
# ...

# %%
test_df = pd.read_csv(TEST_DATASET_PATH)
test_df.tail()
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4995  10379          29    2.0  43.177521   30.339945            5.0      6
# 4996  16138          38    3.0  93.698122   94.521465           10.0     21
# 4997   3912         101    1.0  33.656723   19.003259            5.0      2
# 4998   5722          10    1.0  38.635155   20.976257            9.0      8
# 4999  11004          21    2.0  67.122742   33.944344           13.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4995         5.0       1962   0.069660         B         B        31
# 4996        27.0       2018   0.060753         B         B        15
# 4997         5.0       1966   0.038693         B         B        28
# 4998        14.0       1970   0.089040         B         B        33
# 4999        17.0       2009   0.194489         B         B        47
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
train_df
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809          27    3.0  115.027311         NaN           10.0      4
# 1      3013          22    1.0   39.832524   23.169223            8.0      7
# 2      8215           1    3.0   78.342215   47.671972           10.0      2
# 3      2352           1    1.0   40.409907         NaN            1.0     10
# 4     13866          94    2.0   64.285067   38.562517            9.0     16
# ...     ...         ...    ...         ...         ...            ...    ...
# 9995   1260          61    2.0   49.090728   33.272626            6.0      3
# 9996  16265          27    2.0   64.307684   37.038420            9.0     13
# 9997   2795         178    1.0   29.648057   16.555363            5.0      3
# 9998  14561          21    1.0   32.330292   22.326870            5.0      3
# 9999   7202          94    1.0   35.815476   22.301367            6.0      9
#
# ...

# %%
train_df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
train_df['DistrictId'] = train_df['DistrictId'].astype(int)

# %% [markdown]
# ### Удаление столбца ID. В конечной модели он не понадобится.

# %%
train_df = train_df.drop('Id', axis =1 )

# %%
train_df.describe()
# Out:
#          DistrictId         Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.890500     56.315775    37.199645       6.273300
# std       43.587592      0.839512     21.058732    86.241209      28.560917
# min        0.000000      0.000000      1.136859     0.370619       0.000000
# 25%       20.000000      1.000000     41.774881    22.769832       1.000000
# 50%       36.000000      2.000000     52.513310    32.781260       6.000000
# 75%       75.000000      2.000000     65.900625    45.128803       9.000000
# max      209.000000     19.000000    641.065193  7480.592129    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       8.526700     12.609400  3.990166e+03      0.118858     24.687000
# ...

# %% [markdown]
# ### Обработка выбросов с комнатами. Взято из преподовательсткого решения как наиболее логичное.

# %%
median = train_df['Rooms'].median()
train_df.loc[(train_df['Rooms'] >= 6) | (train_df['Rooms'] == 0), 'Rooms'] = median

# %%
train_df.describe()
# Out:
#          DistrictId         Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.888400     56.315775    37.199645       6.273300
# std       43.587592      0.811056     21.058732    86.241209      28.560917
# min        0.000000      1.000000      1.136859     0.370619       0.000000
# 25%       20.000000      1.000000     41.774881    22.769832       1.000000
# 50%       36.000000      2.000000     52.513310    32.781260       6.000000
# 75%       75.000000      2.000000     65.900625    45.128803       9.000000
# max      209.000000      5.000000    641.065193  7480.592129    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       8.526700     12.609400  3.990166e+03      0.118858     24.687000
# ...

# %% [markdown]
# ### Обзор и обработка пропусков. Замена пропусков средим значением в колонке "Жилая площадь", сохраняя большинство строк датасета.

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     10000 non-null  int32
#  1   Rooms          10000 non-null  float64
#  2   Square         10000 non-null  float64
#  3   LifeSquare     7887 non-null   float64
#  4   KitchenSquare  10000 non-null  float64
#  5   Floor          10000 non-null  int64
#  6   HouseFloor     10000 non-null  float64
#  7   HouseYear      10000 non-null  int64
#  8   Ecology_1      10000 non-null  float64
#  9   Ecology_2      10000 non-null  object
#  10  Ecology_3      10000 non-null  object
#  11  Social_1       10000 non-null  int64
#  12  Social_2       10000 non-null  int64
#  13  Social_3       10000 non-null  int64
#  14  Healthcare_1   5202 non-null   float64
#  15  Helthcare_2    10000 non-null  int64
#  16  Shops_1        10000 non-null  int64
# ...

# %%
mean_LifeSquare = train_df['LifeSquare'].mean()
mean_LifeSquare
# Out:
# 37.199644827673275

# %%
train_df['LifeSquare'] = train_df['LifeSquare'].fillna(mean_LifeSquare)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     10000 non-null  int32
#  1   Rooms          10000 non-null  float64
#  2   Square         10000 non-null  float64
#  3   LifeSquare     10000 non-null  float64
#  4   KitchenSquare  10000 non-null  float64
#  5   Floor          10000 non-null  int64
#  6   HouseFloor     10000 non-null  float64
#  7   HouseYear      10000 non-null  int64
#  8   Ecology_1      10000 non-null  float64
#  9   Ecology_2      10000 non-null  object
#  10  Ecology_3      10000 non-null  object
#  11  Social_1       10000 non-null  int64
#  12  Social_2       10000 non-null  int64
#  13  Social_3       10000 non-null  int64
#  14  Healthcare_1   5202 non-null   float64
#  15  Helthcare_2    10000 non-null  int64
#  16  Shops_1        10000 non-null  int64
# ...

# %%
train_df.describe()
# Out:
#          DistrictId         Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.888400     56.315775     37.199645       6.273300
# std       43.587592      0.811056     21.058732     76.588742      28.560917
# min        0.000000      1.000000      1.136859      0.370619       0.000000
# 25%       20.000000      1.000000     41.774881     25.527399       1.000000
# 50%       36.000000      2.000000     52.513310     37.199645       6.000000
# 75%       75.000000      2.000000     65.900625     41.427234       9.000000
# max      209.000000      5.000000    641.065193   7480.592129    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       8.526700     12.609400  3.990166e+03      0.118858     24.687000
# ...

# %% [markdown]
# ### Обработка выбросов с этажами. Взято из преподовательсткого решения, как наиболее логичное.
# #### Замена этажа на случайный, если номер этажа, на котором находится квартира, окажется больше чем кол-во этажей в доме.

# %%
train_df.loc[train_df['HouseFloor'] == 0, 'HouseFloor'] = train_df['HouseFloor'].median()

# %%
sum(train_df['Floor'] > train_df['HouseFloor'])
# Out:
# 1610

# %%
floor_out = train_df.loc[train_df['Floor'] > train_df['HouseFloor']].index

# %%
train_df.loc[floor_out, 'Floor'] = train_df.loc[floor_out, 'HouseFloor'].apply(lambda x: random.randint(1, x))

# %%
train_df.describe()
# Out:
#          DistrictId         Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.888400     56.315775     37.199645       6.273300
# std       43.587592      0.811056     21.058732     76.588742      28.560917
# min        0.000000      1.000000      1.136859      0.370619       0.000000
# 25%       20.000000      1.000000     41.774881     25.527399       1.000000
# 50%       36.000000      2.000000     52.513310     37.199645       6.000000
# 75%       75.000000      2.000000     65.900625     41.427234       9.000000
# max      209.000000      5.000000    641.065193   7480.592129    2014.000000
#
#              Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.00000  10000.00000  1.000000e+04  10000.000000  10000.000000
# mean       7.39600     12.95910  3.990166e+03      0.118858     24.687000
# ...

# %% [markdown]
# ### Обработка пустых значений колонки "Здравоохранение_1". Так же взято из преподавательского решения.

# %%
train_df.loc[train_df['Healthcare_1'].isnull(), 'Healthcare_1'] = train_df['Healthcare_1'].median()

# %%
len(train_df) - train_df.count()
# Out:
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# Price            0
# dtype: int64

# %% [markdown]
# ###  Обработка выбросов колонок "Общая площадь", "Жилая площадь", "Площадь Кухни".

# %%
LifeSquare_out = train_df.loc[train_df['LifeSquare'] > train_df['Square']].index

# %%
train_df.loc[LifeSquare_out, 'LifeSquare'] = train_df.loc[LifeSquare_out, 'Square']

# %%
KitchenSquare_out = train_df.loc[train_df['KitchenSquare'] > train_df['Square']].index

# %%
train_df.loc[KitchenSquare_out, 'KitchenSquare'] = train_df['KitchenSquare'].median()

# %%
train_df.describe()
# Out:
#          DistrictId         Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.888400     56.315775     36.254713       5.861600
# std       43.587592      0.811056     21.058732     17.216108       5.070426
# min        0.000000      1.000000      1.136859      0.370619       0.000000
# 25%       20.000000      1.000000     41.774881     25.491704       1.000000
# 50%       36.000000      2.000000     52.513310     37.199645       6.000000
# 75%       75.000000      2.000000     65.900625     41.167913       9.000000
# max      209.000000      5.000000    641.065193    638.163193     123.000000
#
#              Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.00000  10000.00000  1.000000e+04  10000.000000  10000.000000
# mean       7.39600     12.95910  3.990166e+03      0.118858     24.687000
# ...

# %% [markdown]
# ###  Обработка выбросов колонки "Год постройки".

# %%
sorted_df = train_df.sort_values(by='HouseYear', ascending=False)
sorted_df
# Out:
#       DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9163         109    1.0   37.265070   20.239714            9.0      9
# 8828         147    2.0   44.791836   28.360393            5.0      4
# 7721          62    1.0   49.298503   49.298503            9.0      9
# 9122          53    2.0   64.233072   47.405440           13.0     13
# 7955          62    1.0   55.911215   43.821379           10.0      6
# ...          ...    ...         ...         ...            ...    ...
# 7610         183    3.0  102.964468   48.322107           14.0      4
# 6250         172    2.0   56.172364   28.384213            7.0      6
# 2066         183    4.0  151.150660   98.187482           23.0      6
# 2795         161    1.0   63.293079   29.389815           18.0      3
# 6794         161    1.0   50.808925   15.920343           20.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# ...

# %%
train_df['HouseYear'] = np.where((train_df.HouseYear == 20052011), 2011, train_df.HouseYear)
train_df['HouseYear'] = np.where((train_df.HouseYear > 2020), 2020, train_df.HouseYear)

# %% [markdown]
# ### Преобразование года постойки в возраст дома (в годах) на текущий момент.

# %%
train_df['HouseYear'] = (2022 - train_df['HouseYear'])

# %%
train_df.rename(columns={'HouseYear': 'Age'}, inplace=True)
train_df
# Out:
#       DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0             27    3.0  115.027311   37.199645           10.0      4
# 1             22    1.0   39.832524   23.169223            8.0      7
# 2              1    3.0   78.342215   47.671972           10.0      2
# 3              1    1.0   40.409907   37.199645            1.0     10
# 4             94    2.0   64.285067   38.562517            9.0     16
# ...          ...    ...         ...         ...            ...    ...
# 9995          61    2.0   49.090728   33.272626            6.0      3
# 9996          27    2.0   64.307684   37.038420            9.0     13
# 9997         178    1.0   29.648057   16.555363            5.0      3
# 9998          21    1.0   32.330292   22.326870            5.0      3
# 9999          94    1.0   35.815476   22.301367            6.0      9
#
#       HouseFloor  Age  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# ...

# %% [markdown]
# ### Обработка Качественных переменных связанных связанных с Экологией и наличеем магазинов.

# %%
train_df['Ecology_2'] = (train_df['Ecology_2'] == 'A').astype(int)

# %%
train_df['Ecology_3'] = (train_df['Ecology_3'] == 'A').astype(int)

# %%
train_df['Shops_2'] = (train_df['Shops_2'] == 'A').astype(int)

# %%
train_df['DistrictId'] = train_df['DistrictId'].astype(int)

# %%
train_df.describe()
# Out:
#          DistrictId         Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.888400     56.315775     36.254713       5.861600
# std       43.587592      0.811056     21.058732     17.216108       5.070426
# min        0.000000      1.000000      1.136859      0.370619       0.000000
# 25%       20.000000      1.000000     41.774881     25.491704       1.000000
# 50%       36.000000      2.000000     52.513310     37.199645       6.000000
# 75%       75.000000      2.000000     65.900625     41.167913       9.000000
# max      209.000000      5.000000    641.065193    638.163193     123.000000
#
#              Floor   HouseFloor          Age     Ecology_1     Ecology_2  \
# count  10000.00000  10000.00000  10000.00000  10000.000000  10000.000000
# mean       7.39600     12.95910     37.12850      0.118858      0.009700
# ...

# %% [markdown]
# ### Построение модели Random forest regressor и проверка ее эффективности.

# %%
feat = ['DistrictId','Rooms', 'Square', 'LifeSquare', 'KitchenSquare', 'Floor', 'HouseFloor', 'Age', 
        'Ecology_1', 'Ecology_2', 'Ecology_3','Social_1', 'Social_2', 'Social_3', 'Healthcare_1', 
        'Helthcare_2', 'Shops_1', 'Shops_2']
x = train_df[feat]
y = train_df['Price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 21)

# %%
forest = RandomForestRegressor()
forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
train_pred = forest.predict(x_train)
test_pred = forest.predict(x_test)
evaluate_preds(y_train, train_pred, y_test, test_pred)
# Out:
# Train R2:	0.962
# Test R2:	0.756

# %% [markdown]
# ### Обработка пропусков в тестовых данных.

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   int64
#  1   DistrictId     5000 non-null   int64
#  2   Rooms          5000 non-null   float64
#  3   Square         5000 non-null   float64
#  4   LifeSquare     3959 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   int64
#  7   HouseFloor     5000 non-null   float64
#  8   HouseYear      5000 non-null   int64
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   object
#  11  Ecology_3      5000 non-null   object
#  12  Social_1       5000 non-null   int64
#  13  Social_2       5000 non-null   int64
#  14  Social_3       5000 non-null   int64
#  15  Healthcare_1   2623 non-null   float64
#  16  Helthcare_2    5000 non-null   int64
# ...

# %%
test_df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.449500    36.158810
# std     4832.674037    44.179466     0.838594    19.092787    17.825287
# min        1.000000     0.000000     0.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.000000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %% [markdown]
# ### При обработке тестового датасета статистические данные берутся с тренировочного датасета.

# %%
median = train_df['Rooms'].median()
test_df.loc[(test_df['Rooms'] >= 6) | (test_df['Rooms'] == 0), 'Rooms'] = median

# %%
test_df['LifeSquare'] = test_df['LifeSquare'].fillna(mean_LifeSquare)

# %%
test_df.loc[test_df['HouseFloor'] == 0, 'HouseFloor'] = train_df['HouseFloor'].median()

# %%
floor_out_test = test_df.loc[test_df['Floor'] > test_df['HouseFloor']].index

# %%
test_df.loc[floor_out_test, 'Floor'] = test_df.loc[floor_out_test, 'HouseFloor'].apply(lambda x: random.randint(1, x))

# %%
test_df.loc[test_df['Healthcare_1'].isnull(), 'Healthcare_1'] = train_df['Healthcare_1'].median()

# %%
LifeSquare_out_test = test_df.loc[test_df['LifeSquare'] > test_df['Square']].index

# %%
test_df.loc[LifeSquare_out_test, 'LifeSquare'] = test_df.loc[LifeSquare_out_test, 'Square']

# %%
KitchenSquare_out_test = test_df.loc[test_df['KitchenSquare'] > test_df['Square']].index

# %%
test_df.loc[KitchenSquare_out_test, 'KitchenSquare'] = train_df['KitchenSquare'].median()

# %%
test_df['HouseYear'] = (2022 - test_df['HouseYear'])

# %%
test_df.rename(columns={'HouseYear': 'Age'}, inplace=True)
test_df
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0      4567          44    1.0  36.847630   19.094182            5.0      5
# 1      5925          62    1.0  42.493907   42.493907           10.0      7
# 2       960          27    2.0  59.463678   37.199645            9.0     19
# 3      3848          23    3.0  49.646030   33.893825            6.0      2
# 4       746          74    1.0  53.837056   37.199645            1.0      8
# ...     ...         ...    ...        ...         ...            ...    ...
# 4995  10379          29    2.0  43.177521   30.339945            5.0      1
# 4996  16138          38    3.0  93.698122   93.698122           10.0     21
# 4997   3912         101    1.0  33.656723   19.003259            5.0      2
# 4998   5722          10    1.0  38.635155   20.976257            9.0      8
# 4999  11004          21    2.0  67.122742   33.944344           13.0      9
#
# ...

# %% [markdown]
# ### Обработка качественных переменных в тестовом датасете.

# %%
test_df['Ecology_2'] = (test_df['Ecology_2'] == 'A').astype(int)

# %%
test_df['Ecology_3'] = (test_df['Ecology_3'] == 'A').astype(int)

# %%
test_df['Shops_2'] = (test_df['Shops_2'] == 'A').astype(int)

# %%
test_df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean    8412.595400    51.279200     1.906200    56.449500    36.196822
# std     4832.674037    44.179466     0.805935    19.092787    15.298760
# min        1.000000     0.000000     1.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    25.848859
# 50%     8320.500000    37.000000     2.000000    52.921340    37.199645
# 75%    12598.250000    77.000000     2.000000    66.285129    41.384025
# max    16795.000000   212.000000     5.000000   223.453689   168.729035
#
#        KitchenSquare        Floor   HouseFloor          Age    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.822800     7.499200    12.941600    37.607400     0.119874
# std         4.633195     5.158849     6.466881    18.573149     0.120070
# ...

# %% [markdown]
# ### Итоговый результат

# %%
forest = RandomForestRegressor()
forest.fit(x, y)
# Out:
# RandomForestRegressor()

# %%
itog_test = test_df[feat]
itog_test = itog_test.fillna(0)
pred = pd.DataFrame(forest.predict(itog_test), columns=['pred'])
pred
# Out:
#                pred
# 0     157216.357411
# 1     114812.140630
# 2     139111.033810
# 3     126366.557015
# 4     209470.932923
# ...             ...
# 4995  173480.575733
# 4996  372889.129787
# 4997  146646.204944
# 4998  193987.134947
# 4999  255015.487896
#
# [5000 rows x 1 columns]

# %%
pred.to_csv('DovbnyaAS_predict.csv')
